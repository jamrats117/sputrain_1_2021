# %% [markdown]
# # Basic Python Exercises

# %% [markdown]
# **1. What is 7 to the power of 4?**

# %% [markdown]
# **2. Split this string:**
#
#     s = "Hi there Sam!"
#
# **into a list.**

# %% [markdown]
# **3. Given the variables:**
#
#     planet = "Earth"
#     diameter = 12742
#
# **How can you print the following string?**
#
#     The diameter of Earth is 12742 kilometers.

# %% [markdown]
# **4. Given this nested list, use indexing to grab the word "hello"**

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %% [markdown]
# **5. Given this nested dictionary grab the word "hello". Be prepared, this will be annoying/tricky**

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %% [markdown]
# **6. What is the main difference between a tuple and a list?**

# %% [markdown]
# **7. What is the different of set1 and set2?**
#
#     set1 = {1, 2, 3, 4, 5}
#     set2 = {3, 4, 5, 6}

# %% [markdown]
# **8. Given**
#
#     num = [2, 3, 6, 8, 10]
#
# **Use "if" statement and "for" loop to print all numbers in "num" if their values are less than 8.**

# %% [markdown]
# **9. Use "while" loop to print numbers starting from 15 to 10 decreasingly by 1.**

# %% [markdown]
# **10. Given**
#
#     animal1 = ['dog', 'cat', 'bird', 'monkey']
#     animal2 = ['chicken', 'cat', 'dog']
#
# **Use "for" loop and "if" statement in generating a new list named "animal3" which has elements in "animal1" but has not in "animal2"**

# %% [markdown]
# **11. Write a function for calculating area of a circle**
#
#     Circle area calculation formular is:
#
#     circle_area = pi*(radius ** 2)
#
#     You can have pi value from
#
#     import math
#     pi = math.pi

# %% [markdown]
# **12. From circle area calculation function in question 11. Use "for" loop for calculating and printing area of 3 circles having radius of 10, 6, and 25 unit respectively.**

# %% [markdown]
# **13. From circle area calculation function in question 11. Use "for" loop and "if" statement for calculating and printing circle areas which their radius listed in a list below if its radius less than 25**
#
#     radius = [4, 9, 10, 25, 20, 30]

# %% [markdown]
# # Great job!
